# %%
import pandas as pd
import re

# %%
# Read the excel file
filepath = 'data/housing_market_Q1/processed/'
input_file_name = 'mw2301-january-city-toronto.xlsx'
df_original = pd.read_excel('{0}{1}'.format(filepath, input_file_name), sheet_name=None)

# %%
df = df_original.copy()

# %%
# Get the sheet names
sheet_names = df.keys()
print(sheet_names)
# Out:
# dict_keys(['all_home_type', 'detached', 'semi_detached', 'townhouse', 'condo_townhouse', 'condo_apartment', 'link', 'coop_apartment', 'detached_condo', 'co_ownership_apartment', 'index_and_benchmark_price'])

# %%
# Load the sheet into a variable
df_semi_detached = df.get('semi_detached')

# %%
# Rename the ;Unnamed: 0' column to 'Area'
df_semi_detached.rename(columns={'Unnamed: 0': 'Area', 'Abc Abc Active Listings':'Active Listings'}, inplace=True)

# %%
df_semi_detached.head()
# Out:
#               Area  Sales Dollar Volume Average Price Median Price
# 0  All TRREB Areas    240  $244,720,268    $1,019,668     $968,965  \
# 1  City of Toronto     84   $96,642,498    $1,150,506   $1,080,444
# 2     Toronto West     25   $26,059,500    $1,042,380     $950,000
# 3      Toronto W01      3    $4,743,000    $1,581,000   $1,350,000
# 4      Toronto W02      3    $3,532,000    $1,177,333   $1,120,000
#
#    New Listings Active Listings Avg. SP/LP  Avg. LDOM
# 0           465        418\nAbc       100%       22.0
# 1           199        200\nAbc       102%       21.0
# 2            53         76\nAbc        99%       30.0
# 3             6          9\nAbc       101%        3.0
# 4            15         14\nAbc        94%       10.0

# %%
for elements in sheet_names:
    print(type(elements))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
def extract_number_from_string(column):
    for i in range(len(column)):
        column[i] = re.findall(r'\d+', column[i])
        column[i] = column[i][0]

column = df_semi_detached['Active Listings']
extract_number_from_string(column)
# Out:
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = re.findall(r'\d+', column[i])
# C:\Users\Shannon\AppData\Local\Temp\ipykernel_10440\1444957305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column[i] = column[i][0]

# %%
df_semi_detached.head()
# Out:
#               Area  Sales Dollar Volume Average Price Median Price
# 0  All TRREB Areas    240  $244,720,268    $1,019,668     $968,965  \
# 1  City of Toronto     84   $96,642,498    $1,150,506   $1,080,444
# 2     Toronto West     25   $26,059,500    $1,042,380     $950,000
# 3      Toronto W01      3    $4,743,000    $1,581,000   $1,350,000
# 4      Toronto W02      3    $3,532,000    $1,177,333   $1,120,000
#
#    New Listings Active Listings Avg. SP/LP  Avg. LDOM
# 0           465             418       100%       22.0
# 1           199             200       102%       21.0
# 2            53              76        99%       30.0
# 3             6               9       101%        3.0
# 4            15              14        94%       10.0

# %%
#outfilepath = 'data/housing_market_Q1/final/'
df_semi_detached.to_excel('data/housing_market_Q1/final/{0}'.format(input_file_name), index = False)
